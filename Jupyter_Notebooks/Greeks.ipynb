# %%
import psycopg2
import pandas as pd

# %%
db_connection = psycopg2.connect(
        user='USER_STRING_HERE', password='PW_STRING_HERE', # Credentials removed for Git,
        host='mads-capstone.cmohac77hep9.eu-north-1.rds.amazonaws.com', port=5432,
        database="mads"
        )

db_connection.autocommit = True

cursor = db_connection.cursor()

# %%
select_query = "SELECT * FROM greeks WHERE ticker='GME'"

cursor.execute(select_query)

rows = cursor.fetchall()

records = []
for row in rows:
    records.append([row[0], row[1],row[2], row[3], row[4], row[5], row[6]])
    
df = pd.DataFrame(records, columns=["ID", "DATE", "INCREMENT", "VALUE", "TICKER", "GREEK", "OPTION_TYPE"])

print(df.shape)

df
# Out:
# (4500, 7)
#            ID        DATE  INCREMENT         VALUE TICKER       GREEK  \
# 0     4637648  2016-08-08          0  3.563000e-01    GME          iv
# 1     4637649  2016-08-08          0  4.721000e-01    GME          iv
# 2     4637650  2016-08-08          0  4.410000e-01    GME          iv
# 3     4637651  2016-08-08          0  1.023084e+06    GME       delta
# 4     4637652  2016-08-08          0  2.963210e+06    GME       delta
# ...       ...         ...        ...           ...    ...         ...
# 4495  8336592  2016-08-16       3600 -3.021014e+06    GME  dual_delta
# 4496  8336593  2016-08-16       3600 -4.775712e+06    GME  dual_delta
# 4497  8336594  2016-08-16       3600  4.228175e+05    GME  dual_gamma
# 4498  8336595  2016-08-16       3600 -6.034876e+05    GME  dual_gamma
# 4499  8336596  2016-08-16       3600 -1.806701e+05    GME  dual_gamma
#
#      OPTION_TYPE
# 0           call
# 1            put
# 2            all
# 3           call
# 4            put
# ...          ...
# 4495         put
# 4496         all
# 4497        call
# 4498         put
# 4499         all
#
# [4500 rows x 7 columns]

# %%
df[df['GREEK'] == 'iv']['VALUE'].round(3)
# Out:
# 0       0.356
# 1       0.472
# 2       0.441
# 45      0.369
# 46      0.398
#         ...
# 4411    0.493
# 4412    0.455
# 4455    0.383
# 4456    0.493
# 4457    0.453
# Name: VALUE, Length: 300, dtype: float64

# %%
df
# Out:
#            ID        DATE  INCREMENT         VALUE TICKER       GREEK  \
# 0     4637648  2016-08-08          0  3.563000e-01    GME          iv
# 1     4637649  2016-08-08          0  4.721000e-01    GME          iv
# 2     4637650  2016-08-08          0  4.410000e-01    GME          iv
# 3     4637651  2016-08-08          0  1.023084e+06    GME       delta
# 4     4637652  2016-08-08          0  2.963210e+06    GME       delta
# ...       ...         ...        ...           ...    ...         ...
# 4495  8336592  2016-08-16       3600 -3.021014e+06    GME  dual_delta
# 4496  8336593  2016-08-16       3600 -4.775712e+06    GME  dual_delta
# 4497  8336594  2016-08-16       3600  4.228175e+05    GME  dual_gamma
# 4498  8336595  2016-08-16       3600 -6.034876e+05    GME  dual_gamma
# 4499  8336596  2016-08-16       3600 -1.806701e+05    GME  dual_gamma
#
#      OPTION_TYPE
# 0           call
# 1            put
# 2            all
# 3           call
# 4            put
# ...          ...
# 4495         put
# 4496         all
# 4497        call
# 4498         put
# 4499         all
#
# [4500 rows x 7 columns]
