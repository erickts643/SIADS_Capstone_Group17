# %%
import re
import nltk
import psycopg2
import pandas as pd
import matplotlib.pyplot as plt
import pytz
import datetime
import seaborn as sns
from collections import Counter
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
nltk.download('stopwords', quiet=True)
from tqdm import tqdm
import boto3
import csv

# %%
bucket = 'mads-capstone-2023' 
data_key = 'FINRA_Short_Sale_Data2.csv' 

s3_client = boto3.client('s3')
obj = s3_client.get_object(Bucket=bucket, Key=data_key)

# %%
#pd.read_csv(obj["Body"].read(), nrows=10)

# %% [markdown]
# cnt = 0
#
# for i, row in enumerate(obj["Body"].iter_lines()):
#     cnt += 1
#
# cnt

# %%
total_records = 8219426

# %%
bucket = 'mads-capstone-2023' 
data_key = 'FINRA_Short_Sale_Data2.csv' 

s3_client = boto3.client('s3')
obj = s3_client.get_object(Bucket=bucket, Key=data_key)

for i, row in enumerate(obj["Body"].iter_lines()):
    if i==0:
        continue
        
    row_data = row.decode().split('"')
    row_data =  row_data[0].split(",") + [row_data[1]] + [row_data[2]]
    row_data = [val for val in row_data if val]
# Out:
# ['0', 'A', '2018-08-01', '127212.0', '14.0', '658064.0', 'Q,N', ',0.1933125045588271']
# ['1', 'AA', '2018-08-01', '514915.0', '817.0', '1549350.0', 'Q,N', ',0.3323425952818924']
# ['2', 'AABA', '2018-08-01', '975797.0', '370.0', '3608955.0', 'Q,N', ',0.27038214663247395']
# ['3', 'AAC', '2018-08-01', '43229.0', '0.0', '93929.0', 'Q,N', ',0.4602305997082903']
# ['4', 'AADR', '2018-08-01', '3213.0', '0.0', '9620.0', 'Q,N', ',0.333991683991684']
# ['5', 'AAL', '2018-08-01', '1373187.0', '3950.0', '2142375.0', 'Q,N', ',0.6409648170838439']

# %%
bucket = 'mads-capstone-2023' 
data_key = 'FINRA_Short_Sale_Data2.csv' 

s3_client = boto3.client('s3')
obj = s3_client.get_object(Bucket=bucket, Key=data_key)

# %%
# %%time

records = []

for i, row in enumerate(obj["Body"].iter_lines()):
    if i == 0:
        continue
    try:
        row_data = row.decode().split(",")
        row_data =  row_data[0].split(",") + [row_data[1]] + [row_data[2]]
        row_data = [val for val in row_data if val]
        idx, ticker, dt, shortvolume, shortexemptvolume, totalvolume, market, short_ratio  = row_data
        dt = dt.split()[0]
        shortvolume = float(shortvolume) if shortvolume else None
        shortexemptvolume = float(shortexemptvolume) if shortexemptvolume else None
        totalvolume = float(totalvolume) if totalvolume else None
        short_ratio = float(short_ratio) if short_ratio else None
    except Exception as e:
        print(e)
        print(f"{i} - {row_data} Failed Parsing.")
        continue

    records.append([dt,incr,opt_value,ticker,greek,opt_type])
    
    print(records)

    if (i%100_000)==0: ## Batching 100k records and uploading all at once.
        df = pd.DataFrame(records)#.dropna()
        df.to_csv("finra.csv", header=False, index=False)
        with open("finra.csv", "rb") as fp:
            cursor.copy_from(fp, "finra", sep=",", null="", columns=["exec_date", "increment", "opt_value", "ticker", "greek", "option_type"])

        records = []
        gc.collect();

        if (i%1_000_000) == 0:
            print(f"{i} Records Inserted")

if records:
    print(len(records))
    df = pd.DataFrame(records)#.dropna()
    df.to_csv("finra.csv", header=False, index=False)
    with open("finra.csv", "rb") as fp:
        cursor.copy_from(fp, "finra", sep=",", null="", columns=["exec_date", "increment", "opt_value", "ticker", "greek", "option_type"])
# Out:
# not enough values to unpack (expected 8, got 3)
# 1 - ['0', 'A', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 2 - ['1', 'AA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 3 - ['2', 'AABA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 4 - ['3', 'AAC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 5 - ['4', 'AADR', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 6 - ['5', 'AAL', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 7 - ['6', 'AAMC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 8 - ['7', 'AAME', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 9 - ['8', 'AAN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 10 - ['9', 'AAOI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 11 - ['10', 'AAON', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 12 - ['11', 'AAP', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 13 - ['12', 'AAPL', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 14 - ['13', 'AAT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 15 - ['14', 'AAU', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 16 - ['15', 'AAV', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 17 - ['16', 'AAWW', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 18 - ['17', 'AAXJ', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 19 - ['18', 'AAXN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 20 - ['19', 'AB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 21 - ['20', 'ABAC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 22 - ['21', 'ABB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 23 - ['22', 'ABBV', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 24 - ['23', 'ABC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 25 - ['24', 'ABCB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 26 - ['25', 'ABCD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 27 - ['26', 'ABDC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 28 - ['27', 'ABEO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 29 - ['28', 'ABEV', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 30 - ['29', 'ABG', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 31 - ['30', 'ABIL', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 32 - ['31', 'ABIO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 33 - ['32', 'ABM', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 34 - ['33', 'ABMD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 35 - ['34', 'ABR', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 36 - ['35', 'ABT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 37 - ['36', 'ABTX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 38 - ['37', 'ABUS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 39 - ['38', 'ABX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 40 - ['39', 'AC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 41 - ['40', 'ACAD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 42 - ['41', 'ACBI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 43 - ['42', 'ACC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 44 - ['43', 'ACCO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 45 - ['44', 'ACER', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 46 - ['45', 'ACET', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 47 - ['46', 'ACGL', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 48 - ['47', 'ACGLO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 49 - ['48', 'ACGLP', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 50 - ['49', 'ACH', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 51 - ['50', 'ACHC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 52 - ['51', 'ACHN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 53 - ['52', 'ACHV', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 54 - ['53', 'ACIA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 55 - ['54', 'ACIM', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 56 - ['55', 'ACIU', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 57 - ['56', 'ACIW', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 58 - ['57', 'ACLS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 59 - ['58', 'ACM', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 60 - ['59', 'ACMR', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 61 - ['60', 'ACN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 62 - ['61', 'ACNB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 63 - ['62', 'ACOR', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 64 - ['63', 'ACP', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 65 - ['64', 'ACRE', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 66 - ['65', 'ACRS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 67 - ['66', 'ACRX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 68 - ['67', 'ACSF', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 69 - ['68', 'ACST', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 70 - ['69', 'ACT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 71 - ['70', 'ACTG', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 72 - ['71', 'ACU', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 73 - ['72', 'ACV', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 74 - ['73', 'ACWF', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 75 - ['74', 'ACWI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 76 - ['75', 'ACWV', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 77 - ['76', 'ACWX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 78 - ['77', 'ACXM', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 79 - ['78', 'ACY', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 80 - ['79', 'ADAP', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 81 - ['80', 'ADBE', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 82 - ['81', 'ADC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 83 - ['82', 'ADES', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 84 - ['83', 'ADI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 85 - ['84', 'ADIL', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 86 - ['85', 'ADILW', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 87 - ['86', 'ADM', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 88 - ['87', 'ADMA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 89 - ['88', 'ADMP', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 90 - ['89', 'ADMS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 91 - ['90', 'ADNT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 92 - ['91', 'ADOM', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 93 - ['92', 'ADP', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 94 - ['93', 'ADRD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 95 - ['94', 'ADRE', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 96 - ['95', 'ADRO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 97 - ['96', 'ADS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 98 - ['97', 'ADSK', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 99 - ['98', 'ADSW', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 100 - ['99', 'ADT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 101 - ['100', 'ADTN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 102 - ['101', 'ADUS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 103 - ['102', 'ADVM', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 104 - ['103', 'ADX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 105 - ['104', 'ADXS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 106 - ['105', 'AE', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 107 - ['106', 'AEB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 108 - ['107', 'AED', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 109 - ['108', 'AEE', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 110 - ['109', 'AEF', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 111 - ['110', 'AEG', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 112 - ['111', 'AEGN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 113 - ['112', 'AEH', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 114 - ['113', 'AEHR', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 115 - ['114', 'AEIS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 116 - ['115', 'AEL', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 117 - ['116', 'AEM', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 118 - ['117', 'AEMD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 119 - ['118', 'AEO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 120 - ['119', 'AEP', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 121 - ['120', 'AER', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 122 - ['121', 'AERI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 123 - ['122', 'AES', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 124 - ['123', 'AET', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 125 - ['124', 'AETI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 126 - ['125', 'AEZS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 127 - ['126', 'AFB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 128 - ['127', 'AFC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 129 - ['128', 'AFG', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 130 - ['129', 'AFGE', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 131 - ['130', 'AFGH', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 132 - ['131', 'AFH', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 133 - ['132', 'AFHBL', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 134 - ['133', 'AFI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 135 - ['134', 'AFIN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 136 - ['135', 'AFK', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 137 - ['136', 'AFL', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 138 - ['137', 'AFMD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 139 - ['138', 'AFSI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 140 - ['139', 'AFSIpA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 141 - ['140', 'AFSIpB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 142 - ['141', 'AFSIpC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 143 - ['142', 'AFSIpD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 144 - ['143', 'AFSIpE', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 145 - ['144', 'AFSIpF', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 146 - ['145', 'AFSS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 147 - ['146', 'AFST', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 148 - ['147', 'AFT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 149 - ['148', 'AFTY', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 150 - ['149', 'AG', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 151 - ['150', 'AGC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 152 - ['151', 'AGCO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 153 - ['152', 'AGD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 154 - ['153', 'AGEN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 155 - ['154', 'AGFS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 156 - ['155', 'AGG', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 157 - ['156', 'AGGP', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 158 - ['157', 'AGGY', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 159 - ['158', 'AGI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 160 - ['159', 'AGIO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 161 - ['160', 'AGLE', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 162 - ['161', 'AGM', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 163 - ['162', 'AGMH', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 164 - ['163', 'AGMpB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 165 - ['164', 'AGN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 166 - ['165', 'AGNC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 167 - ['166', 'AGNCB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 168 - ['167', 'AGNCN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 169 - ['168', 'AGND', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 170 - ['169', 'AGO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 171 - ['170', 'AGOpB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 172 - ['171', 'AGOpE', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 173 - ['172', 'AGQ', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 174 - ['173', 'AGR', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 175 - ['174', 'AGRO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 176 - ['175', 'AGRX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 177 - ['176', 'AGS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 178 - ['177', 'AGT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 179 - ['178', 'AGTC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 180 - ['179', 'AGX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 181 - ['180', 'AGYS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 182 - ['181', 'AGZ', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 183 - ['182', 'AGZD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 184 - ['183', 'AHC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 185 - ['184', 'AHH', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 186 - ['185', 'AHL', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 187 - ['186', 'AHLpC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 188 - ['187', 'AHLpD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 189 - ['188', 'AHPI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 190 - ['189', 'AHT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 191 - ['190', 'AHTpD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 192 - ['191', 'AHTpF', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 193 - ['192', 'AHTpG', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 194 - ['193', 'AHTpH', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 195 - ['194', 'AHTpI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 196 - ['195', 'AI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 197 - ['196', 'AIA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 198 - ['197', 'AIC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 199 - ['198', 'AIEQ', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 200 - ['199', 'AIF', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 201 - ['200', 'AIG', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 202 - ['201', 'AIG/WS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 203 - ['202', 'AIHS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 204 - ['203', 'AIIQ', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 205 - ['204', 'AIMC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 206 - ['205', 'AIMT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 207 - ['206', 'AIN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 208 - ['207', 'AINC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 209 - ['208', 'AINV', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 210 - ['209', 'AIPT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 211 - ['210', 'AIQ', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 212 - ['211', 'AIR', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 213 - ['212', 'AIRG', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 214 - ['213', 'AIRI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 215 - ['214', 'AIRR', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 216 - ['215', 'AIRT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 217 - ['216', 'AIT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 218 - ['217', 'AIV', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 219 - ['218', 'AIW', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 220 - ['219', 'AIY', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 221 - ['220', 'AIZ', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 222 - ['221', 'AJG', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 223 - ['222', 'AJRD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 224 - ['223', 'AJX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 225 - ['224', 'AKAM', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 226 - ['225', 'AKAO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 227 - ['226', 'AKBA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 228 - ['227', 'AKCA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 229 - ['228', 'AKER', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 230 - ['229', 'AKG', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 231 - ['230', 'AKO/B', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 232 - ['231', 'AKP', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 233 - ['232', 'AKR', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 234 - ['233', 'AKRX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 235 - ['234', 'AKS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 236 - ['235', 'AKTS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 237 - ['236', 'AKTX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 238 - ['237', 'AL', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 239 - ['238', 'ALB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 240 - ['239', 'ALBO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 241 - ['240', 'ALCO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 242 - ['241', 'ALD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 243 - ['242', 'ALDR', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 244 - ['243', 'ALDX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 245 - ['244', 'ALE', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 246 - ['245', 'ALEX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 247 - ['246', 'ALFA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 248 - ['247', 'ALG', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 249 - ['248', 'ALGN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 250 - ['249', 'ALGT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 251 - ['250', 'ALIM', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 252 - ['251', 'ALJJ', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 253 - ['252', 'ALK', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 254 - ['253', 'ALKS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 255 - ['254', 'ALL', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 256 - ['255', 'ALLE', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 257 - ['256', 'ALLK', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 258 - ['257', 'ALLT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 259 - ['258', 'ALLY', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 260 - ['259', 'ALLYpA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 261 - ['260', 'ALLpA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 262 - ['261', 'ALLpB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 263 - ['262', 'ALLpC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 264 - ['263', 'ALLpD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 265 - ['264', 'ALLpE', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 266 - ['265', 'ALLpF', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 267 - ['266', 'ALLpG', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 268 - ['267', 'ALN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 269 - ['268', 'ALNA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 270 - ['269', 'ALNY', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 271 - ['270', 'ALO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 272 - ['271', 'ALOT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 273 - ['272', 'ALPN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 274 - ['273', 'ALPpQ', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 275 - ['274', 'ALQA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 276 - ['275', 'ALRM', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 277 - ['276', 'ALRN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 278 - ['277', 'ALSK', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 279 - ['278', 'ALSN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 280 - ['279', 'ALT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 281 - ['280', 'ALTR', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 282 - ['281', 'ALTY', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 283 - ['282', 'ALV', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 284 - ['283', 'ALX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 285 - ['284', 'ALXN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 286 - ['285', 'AM', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 287 - ['286', 'AMAG', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 288 - ['287', 'AMAT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 289 - ['288', 'AMBA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 290 - ['289', 'AMBC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 291 - ['290', 'AMBCW', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 292 - ['291', 'AMBO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 293 - ['292', 'AMBR', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 294 - ['293', 'AMC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 295 - ['294', 'AMCN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 296 - ['295', 'AMCX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 297 - ['296', 'AMD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 298 - ['297', 'AMDA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 299 - ['298', 'AME', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 300 - ['299', 'AMED', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 301 - ['300', 'AMEH', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 302 - ['301', 'AMG', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 303 - ['302', 'AMGN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 304 - ['303', 'AMGP', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 305 - ['304', 'AMH', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 306 - ['305', 'AMHpD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 307 - ['306', 'AMHpE', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 308 - ['307', 'AMHpF', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 309 - ['308', 'AMHpG', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 310 - ['309', 'AMID', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 311 - ['310', 'AMJ', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 312 - ['311', 'AMJL', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 313 - ['312', 'AMKR', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 314 - ['313', 'AMLP', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 315 - ['314', 'AMMA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 316 - ['315', 'AMN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 317 - ['316', 'AMNB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 318 - ['317', 'AMOT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 319 - ['318', 'AMP', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 320 - ['319', 'AMPE', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 321 - ['320', 'AMPH', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 322 - ['321', 'AMR', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 323 - ['322', 'AMRB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 324 - ['323', 'AMRC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 325 - ['324', 'AMRH', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 326 - ['325', 'AMRK', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 327 - ['326', 'AMRN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 328 - ['327', 'AMRS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 329 - ['328', 'AMRX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 330 - ['329', 'AMS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 331 - ['330', 'AMSC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 332 - ['331', 'AMSF', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 333 - ['332', 'AMSWA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 334 - ['333', 'AMT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 335 - ['334', 'AMTD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 336 - ['335', 'AMTX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 337 - ['336', 'AMU', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 338 - ['337', 'AMWD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 339 - ['338', 'AMX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 340 - ['339', 'AMZA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 341 - ['340', 'AMZN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 342 - ['341', 'AN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 343 - ['342', 'ANAB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 344 - ['343', 'ANAT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 345 - ['344', 'ANCB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 346 - ['345', 'ANCX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 347 - ['346', 'ANDE', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 348 - ['347', 'ANDV', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 349 - ['348', 'ANDX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 350 - ['349', 'ANET', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 351 - ['350', 'ANF', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 352 - ['351', 'ANFI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 353 - ['352', 'ANGI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 354 - ['353', 'ANGL', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 355 - ['354', 'ANGO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 356 - ['355', 'ANH', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 357 - ['356', 'ANHpC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 358 - ['357', 'ANIK', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 359 - ['358', 'ANIP', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 360 - ['359', 'ANSS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 361 - ['360', 'ANTM', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 362 - ['361', 'ANW', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 363 - ['362', 'ANY', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 364 - ['363', 'AOA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 365 - ['364', 'AOBC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 366 - ['365', 'AOD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 367 - ['366', 'AOI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 368 - ['367', 'AOK', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 369 - ['368', 'AOM', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 370 - ['369', 'AON', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 371 - ['370', 'AOR', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 372 - ['371', 'AOS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 373 - ['372', 'AOSL', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 374 - ['373', 'AP', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 375 - ['374', 'APA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 376 - ['375', 'APAM', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 377 - ['376', 'APC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 378 - ['377', 'APD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 379 - ['378', 'APDN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 380 - ['379', 'APEI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 381 - ['380', 'APEN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 382 - ['381', 'APF', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 383 - ['382', 'APH', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 384 - ['383', 'APHB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 385 - ['384', 'APLE', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 386 - ['385', 'APLS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 387 - ['386', 'APO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 388 - ['387', 'APOG', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 389 - ['388', 'APOP', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 390 - ['389', 'APOpA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 391 - ['390', 'APOpB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 392 - ['391', 'APPF', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 393 - ['392', 'APPN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 394 - ['393', 'APPS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 395 - ['394', 'APRI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 396 - ['395', 'APRN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 397 - ['396', 'APT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 398 - ['397', 'APTI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 399 - ['398', 'APTO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 400 - ['399', 'APTS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 401 - ['400', 'APTV', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 402 - ['401', 'APTX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 403 - ['402', 'APU', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 404 - ['403', 'APVO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 405 - ['404', 'APY', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 406 - ['405', 'AQ', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 407 - ['406', 'AQB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 408 - ['407', 'AQMS', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 409 - ['408', 'AQN', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 410 - ['409', 'AQST', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 411 - ['410', 'AQUA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 412 - ['411', 'AQXP', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 413 - ['412', 'AR', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 414 - ['413', 'ARA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 415 - ['414', 'ARAY', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 416 - ['415', 'ARC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 417 - ['416', 'ARCB', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 418 - ['417', 'ARCC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 419 - ['418', 'ARCH', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 420 - ['419', 'ARCI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 421 - ['420', 'ARCO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 422 - ['421', 'ARCT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 423 - ['422', 'ARD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 424 - ['423', 'ARDC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 425 - ['424', 'ARDM', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 426 - ['425', 'ARDX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 427 - ['426', 'ARE', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 428 - ['427', 'ARES', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 429 - ['428', 'ARESpA', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 430 - ['429', 'AREX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 431 - ['430', 'AREpD', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 432 - ['431', 'ARGO', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 433 - ['432', 'ARGT', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 434 - ['433', 'ARGX', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 435 - ['434', 'ARI', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 436 - ['435', 'ARII', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 437 - ['436', 'ARIpC', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 438 - ['437', 'ARKG', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
# 439 - ['438', 'ARKK', '2018-08-01'] Failed Parsing.
# not enough values to unpack (expected 8, got 3)
#